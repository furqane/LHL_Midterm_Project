# %%
import pandas as pd

# %%
df = pd.read_csv('ftest_to_encode.csv', index_col=[0])
df = df.drop(['mkt_unique_carrier'],axis=1) #this feature was not used in XGBoost
df.reset_index(drop=True, inplace=True)
df
# Out:
#            fl_date origin_city_name  dest_city_name  crs_dep_time  \
# 0       2020-01-01      Ontario, CA    San Jose, CA          2020
# 1       2020-01-01      Ontario, CA    San Jose, CA          1340
# 2       2020-01-01      Ontario, CA    San Jose, CA           915
# 3       2020-01-01      Ontario, CA    San Jose, CA           600
# 4       2020-01-01      Ontario, CA    San Jose, CA          1620
# ...            ...              ...             ...           ...
# 244055  2020-01-30     New York, NY    Richmond, VA          1642
# 244056  2020-01-30     Richmond, VA    New York, NY          1900
# 244057  2020-01-30   Cincinnati, OH  Washington, DC          1655
# 244058  2020-01-30     New York, NY  Burlington, VT          2205
# 244059  2020-01-30     New York, NY   Charlotte, NC          2005
#
#         crs_arr_time  crs_elapsed_time  distance  Passengers_Seat_Ratio  \
# 0               2130                70       333               0.721639
# ...

# %%
predicted_df = pd.read_csv('predicted_df.csv', index_col=[0])
predicted_df.reset_index(drop=True, inplace=True)
predicted_df
# Out:
#         predicted_delay
# 0             -3.247165
# 1             -6.271799
# 2             10.167065
# 3              9.698260
# 4             -5.604271
# ...                 ...
# 244055        75.217620
# 244056        43.647590
# 244057         4.482183
# 244058        51.418526
# 244059        73.489490
#
# [244060 rows x 1 columns]

# %%
submission_df = pd.concat([df,predicted_df],axis=1)

# %%
submission_df.head(2)
# Out:
#       fl_date origin_city_name dest_city_name  crs_dep_time  crs_arr_time  \
# 0  2020-01-01      Ontario, CA   San Jose, CA          2020          2130
# 1  2020-01-01      Ontario, CA   San Jose, CA          1340          1455
#
#    crs_elapsed_time  distance  Passengers_Seat_Ratio  \
# 0                70       333               0.721639
# 1                75       333               0.721639
#
#    mkt_op_carrier_difference  Taxi_Holdup Type_Mode  predicted_delay
# 0                       True    12.158385       Fog        -3.247165
# 1                       True    12.598257       Fog        -6.271799

# %%
submission_df.to_csv('submission_csv.csv')
